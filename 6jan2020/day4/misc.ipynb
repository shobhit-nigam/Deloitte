# %%
lista = [20, 33, 12, 19]

# %%
print(sorted(lista))
# Out:
# [12, 19, 20, 33]

# %%
listb = ['Insidious', 'evil dead', 'conjuring', 'babadook']

# %%
sorted(listb)
# Out:
# ['Insidious', 'babadook', 'conjuring', 'evil dead']

# %%
sorted(listb, key=len)
# Out:
# ['babadook', 'Insidious', 'evil dead', 'conjuring']

# %%
sorted(listb, key=str.lower)
# Out:
# ['babadook', 'conjuring', 'evil dead', 'Insidious']

# %%
listb = ['Insidious', 'evil dead', 'conjuring', 'babadook', 'Anabelle']

# %%
sorted(listb, key=str.lower)
# Out:
# ['Anabelle', 'babadook', 'conjuring', 'evil dead', 'Insidious']

# %%
def funca(strb):
    return strb[-1]

# %%
sorted(listb, key=funca)
# Out:
# ['evil dead', 'Anabelle', 'conjuring', 'babadook', 'Insidious']

# %%
#     regular expressions

# %%
vara = input()
# Out:
# 453

# %%
print(vara)
# Out:
# 453

# %%
type(vara)
# Out:
# str

# %%
vara = input("please input only integers: ")
# Out:
# please input only integers: 567

# %%
vara = int(input("please input only integers: "))
# Out:
# please input only integers: 567

# %%
type(vara)
# Out:
# int

# %%
varb = int(input("please input only integers: "))
# Out:
# please input only integers: hello
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-d5821404998e> in <module>
# ----> 1 varb = int(input("please input only integers: "))
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
varb = int(input("please input only integers: "))
# Out:
# please input only integers: 34.67
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-d5821404998e> in <module>
# ----> 1 varb = int(input("please input only integers: "))
#
# ValueError: invalid literal for int() with base 10: '34.67'

# %%
varb = int(input("please input only integers: "))
# Out:
# please input only integers: 666

# %%
eval('4+3*2')
# Out:
# 10

# %%
eval('vara==varb')
# Out:
# False

# %%
varc = eval(input())
# Out:
# 45

# %%
type(varc)
# Out:
# int

# %%
varc = eval(input())
# Out:
# 56.89

# %%
type(varc)
# Out:
# float

# %%
vard = eval(input())
# Out:
# 'hello'

# %%
type(vard)
# Out:
# str

# %%
vard = eval(input())
# Out:
# varc

# %%
type(vard)
# Out:
# float

# %%
vard
# Out:
# 56.89

# %%
vard = eval(input())
# Out:
# hello
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-ff2531cce17f> in <module>
# ----> 1 vard = eval(input())
#
# <string> in <module>
#
# NameError: name 'hello' is not defined
