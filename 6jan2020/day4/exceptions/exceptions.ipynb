# %%
vara =
# Out:
#   File "<ipython-input-1-01a15250065f>", line 1
#     vara =
#            ^
# SyntaxError: invalid syntax

# %%
vara = 10
vara = 20
varc = 0

# %%
varb = vara/varc
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-3-714f97a75efc> in <module>
# ----> 1 varb = vara/varc
#
# ZeroDivisionError: division by zero

# %%
lista = []
avg = 0

# %%
try:
    varb = vara/varc
    print(vara)
except ZeroDivisionError:
    print("divide by zero not possible")
# Out:
# divide by zero not possible

# %%
try:
    avg = sum(lista)/len(lista)
    print("avg is ", avg)
except ZeroDivisionError:
    print("list is empty")
# Out:
# list is empty

# %%
lista.append(20)

# %%
try:
    avg = sum(lista)/len(lista)
    print("avg is ", avg)
except ZeroDivisionError:
    print("list is empty")
# Out:
# avg is  20.0

# %%
lista.clear()

try:
    avg = sum(listb)/len(lista)
    print("avg is ", avg)
except ZeroDivisionError:
    print("list is empty")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-64541090c37a> in <module>
#       2
#       3 try:
# ----> 4     avg = sum(listb)/len(lista)
#       5     print("avg is ", avg)
#       6 except ZeroDivisionError:
#
# NameError: name 'listb' is not defined

# %%
try:
    avg = sum(listb)/len(lista)
    print("avg is ", avg)
except ZeroDivisionError:
    print("list is empty")
except NameError:
    print("check your name please")
# Out:
# check your name please

# %%
try:
    avg = sum(listb)/len(lista)
    print("avg is ", avg)
except ZeroDivisionError:
    print("list is empty")
except NameError:
    print("check your name please")
print('hi')
# Out:
# check your name please
# hi

# %%
a = 12/6/2

# %%
a
# Out:
# 1.0

# %%
listb = [6, 8, 10]
lista = listb

# %%
try:
    avg = sum(listb)/len(lista)
    print("avg is ", avg)
except ZeroDivisionError:
    print("list is empty")
except NameError:
    print("check your name please")
print('hi')
# Out:
# avg is  8.0
# hi

# %%
try:
    i = eval(input("enter index: "))
    avg = sum(listb)/len(lista)
    print("avg is ", avg)
    val = lista[i]
    print("val =", val)
except ZeroDivisionError:
    print("list is empty")
except NameError:
    print("check your name please")
print('hi')
# Out:
# enter index: 1
# avg is  8.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-0c375d9a12f8> in <module>
#       3     avg = sum(listb)/len(lista)
#       4     print("avg is ", avg)
# ----> 5     val = lista[i]
#       6     print("val =", val)
#       7 except ZeroDivisionError:
#
# TypeError: list indices must be integers or slices, not str

# %%
try:
    i = eval(input("enter index: "))
    avg = sum(listb)/len(lista)
    print("avg is ", avg)
    val = lista[i]
    print("val =", val)
except ZeroDivisionError:
    print("list is empty")
except NameError:
    print("check your name please")
print('hi')
# Out:
# enter index: 1
# avg is  8.0
# val = 8
# hi

# %%
try:
    i = input("enter index: ")
    avg = sum(listb)/len(lista)
    print("avg is ", avg)
    val = lista[i]
    print("val =", val)
except ZeroDivisionError:
    print("list is empty")
except NameError:
    print("check your name please")
except TypeError:
    print(lista[int(i)])
print('hi')
# Out:
# enter index: 1
# avg is  8.0
# 8
# hi

# %%
try:
    i = input("enter index: ")
    avg = sum(listb)/len(lista)
    print("avg is ", avg)
    val = lista[i]
    print("val =", val)
except ZeroDivisionError:
    print("list is empty")
except NameError:
    print("check your name please")
except TypeError:
    print(lista[int(i)])
except IndexError:
    print("out of index")
print('hi')
# Out:
# enter index: 4
# avg is  8.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-85cc10476588> in <module>
#       4     print("avg is ", avg)
# ----> 5     val = lista[i]
#       6     print("val =", val)
#
# TypeError: list indices must be integers or slices, not str
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-85cc10476588> in <module>
#      10     print("check your name please")
#      11 except TypeError:
# ---> 12     print(lista[int(i)])
#      13 print('hi')
#
# IndexError: list index out of range

# %%
try:
    i = input("enter index: ")
    avg = sum(listb)/len(lista)
    print("avg is ", avg)
    val = lista[i]
    print("val =", val)
except ZeroDivisionError:
    print("list is empty")
except NameError:
    print("check your name please")
except TypeError:
    print(lista[int(i)])
except IndexError:
    print("out of index")
print('hi')
# Out:
# enter index: 4
# avg is  8.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-6e5f7326604b> in <module>
#       4     print("avg is ", avg)
# ----> 5     val = lista[i]
#       6     print("val =", val)
#
# TypeError: list indices must be integers or slices, not str
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-6e5f7326604b> in <module>
#      10     print("check your name please")
#      11 except TypeError:
# ---> 12     print(lista[int(i)])
#      13 except IndexError:
#      14     print("out of index")
#
# IndexError: list index out of range

# %%
try:
    i = input("enter index: ")
    avg = sum(listb)/len(lista)
    print("avg is ", avg)
    val = lista[i]
    print("val =", val)
except ZeroDivisionError:
    print("list is empty")
except NameError:
    print("check your name please")
except:
    print("something went wrong, don't know what")
print("hi")
# Out:
# enter index: 4
# avg is  8.0
# something went wrong, don't know what
# hi

# %%
try:
    i = input("enter index: ")
    avg = sum(listb)/len(lista)
    print("avg is ", avg)
    val = lista[i]
    print("val =", val)
except:
    print("something went wrong, don't know what")
except ZeroDivisionError:
    print("list is empty")
except NameError:
    print("check your name please")
print("hi")
# Out:
#   File "<ipython-input-23-36cf48c08347>", line 9
#     except ZeroDivisionError:
#
# ^
# SyntaxError: default 'except:' must be last

# %%
try:
    i = input("enter index: ")
    avg = sum(listb)/len(lista)
    print("avg is ", avg)
    val = lista[i]
    print("val =", val)
print("hello")
except ZeroDivisionError:
    print("list is empty")
except NameError:
    print("check your name please")
except:
    print("something went wrong, don't know what")
print("hi")
# Out:
#   File "<ipython-input-24-949c53bfb10e>", line 7
#     print("hello")
#         ^
# SyntaxError: invalid syntax

# %%
try:
    i = eval(input("enter index: "))
    avg = sum(listb)/len(lista)
    print("avg is ", avg)
    val = lista[i]
    print("val =", val)
except ZeroDivisionError:
    print("list is empty")
except NameError:
    print("check your name please")
except:
    print("something went wrong, don't know what")
# Out:
#   File "<ipython-input-25-5747e308b4fa>", line 7
#     print("hello")
#         ^
# SyntaxError: invalid syntax

# %%
try:
    age = eval(input("enter age: "))
    if age < 18:
        raise ValueError("age is too less")
    else :
        print("good to go")
except ValueError :
    print("underage")
# Out:
# enter age: 12
# underage

# %%
try:
    age = eval(input("enter age: "))
    if age < 18:
        raise ValueError("age is too less")
    else :
        print("good to go")
except :
    pass
# Out:
# enter age: 12

# %%
try:
    try:
        age = eval(input("enter age: "))
        if age < 18:
            raise ValueError("age is too less")
        else :
            print("your age =", aje)
    except ValueError:
        print("inner value error")
except NameError:
    print("outer name error")
# Out:
# enter age: 22
# outer name error

# %%
def funca(num):
    try:
        age = eval(input("enter age: "))
        if age < num:
            raise ValueError("age is too less")
        else :
            print("your age =", age)
    except ValueError:
        print("inner value error")
    return

# %%
try:
    funca(20)
except:
    print('something went wrong')
# Out:
# enter age: 22
# your age = 22

# %%
try:
    funca(20)
except:
    print('something went wrong')
# Out:
# enter age: 18
# inner value error

# %%
def funca(num):
    try:
        age = eval(input("enter age: "))
        if age < num:
            raise ValueError("age is too less")
        else :
            print("your age =", aje)
    except ValueError:
        print("inner value error")
    return

# %%
try:
    funca(20)
except:
    print('something went wrong')
# Out:
# enter age: 22
# something went wrong

# %%
try:
    i = eval(input("enter index"))
    val = lista[i]
except IndexError:
    print("the index is wrong")
except :
    print("something went wrong")
else :
    print(val)
# Out:
# enter index1
# 8

# %%
try:
    i = eval(input("enter index: "))
    val = lista[i]
except IndexError:
    print("the index is wrong")
else :
    print(val)
finally:
    print("this will execute irrespective")

print("last line")
# Out:
# enter index: 2
# 10
# this will execute irrespective
# last line
