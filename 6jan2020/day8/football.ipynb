# %%
import pandas as pd

# %%
dfa = pd.read_csv('results.csv')

# %%
dfa
# Out:
#              date     home_team    away_team  home_score  away_score  \
# 0      1872-11-30      Scotland      England           0           0
# 1      1873-03-08       England     Scotland           4           2
# 2      1874-03-07      Scotland      England           2           1
# 3      1875-03-06       England     Scotland           2           2
# 4      1876-03-04      Scotland      England           3           0
# ...           ...           ...          ...         ...         ...
# 41535  2019-11-19    Kyrgyzstan   Tajikistan           1           1
# 41536  2019-11-19       Vietnam     Thailand           0           0
# 41537  2019-11-19      Malaysia    Indonesia           2           0
# 41538  2019-11-19  Turkmenistan    Sri Lanka           2           0
# 41539  2019-11-19       Lebanon  North Korea           0           0
#
#                          tournament          city       country  neutral
# ...

# %%
dfa.shape
# Out:
# (41540, 9)

# %%
dfa.columns
# Out:
# Index(['date', 'home_team', 'away_team', 'home_score', 'away_score',
#        'tournament', 'city', 'country', 'neutral'],
#       dtype='object')

# %%
dfa['tournament'].valuecounts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-a20f684f1743> in <module>
# ----> 1 dfa['tournament'].valuecounts()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'valuecounts'

# %%
listx = list(dfa['tournament'].unique())

# %%
listx
# Out:
# ['Friendly',
#  'British Championship',
#  'Copa Lipton',
#  'Copa Newton',
#  'Copa Premio Honor Argentino',
#  'Copa Premio Honor Uruguayo',
#  'Copa Roca',
#  'Copa América',
#  'Copa Chevallier Boutell',
#  'Nordic Championship',
#  'International Cup',
#  'Baltic Cup',
#  'Balkan Cup',
#  'FIFA World Cup',
#  'Copa Rio Branco',
#  'FIFA World Cup qualification',
#  'CCCF Championship',
#  'NAFU Championship',
#  'Copa Oswaldo Cruz',
#  'Pan American Championship',
#  'Copa del Pacífico',
#  "Copa Bernardo O'Higgins",
#  'AFC Asian Cup qualification',
#  'Atlantic Cup',
#  'AFC Asian Cup',
#  'African Cup of Nations',
#  'Copa Paz del Chaco',
#  'Merdeka Tournament',
#  'UEFA Euro qualification',
#  'UEFA Euro',
#  'Windward Islands Tournament',
#  'African Cup of Nations qualification',
#  'Vietnam Independence Cup',
#  'Copa Carlos Dittborn',
#  'CONCACAF Championship',
#  'Copa Juan Pinto Durán',
#  'UAFA Cup',
#  'South Pacific Games',
# ...

# %%
len(listx)
# Out:
# 112

# %%
dfa['tournament'].unique().value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-bf4da59d864d> in <module>
# ----> 1 dfa['tournament'].unique().value_counts()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'value_counts'

# %%
dfa.tournament.value_counts()
# Out:
# Friendly                                17036
# FIFA World Cup qualification             7236
# UEFA Euro qualification                  2582
# African Cup of Nations qualification     1672
# FIFA World Cup                            900
#                                         ...
# Dragon Cup                                  4
# OSN Cup                                     4
# Atlantic Heritage Cup                       2
# Copa América qualification                  2
# AFF Championship qualification              2
# Name: tournament, Length: 112, dtype: int64

# %%
pd.to_datetime(dfa.date).head()
# Out:
# 0   1872-11-30
# 1   1873-03-08
# 2   1874-03-07
# 3   1875-03-06
# 4   1876-03-04
# Name: date, dtype: datetime64[ns]

# %%
dfa['year'] = pd.DatetimeIndex(dfa['date']).year

# %%
dfa
# Out:
#              date     home_team    away_team  home_score  away_score  \
# 0      1872-11-30      Scotland      England           0           0
# 1      1873-03-08       England     Scotland           4           2
# 2      1874-03-07      Scotland      England           2           1
# 3      1875-03-06       England     Scotland           2           2
# 4      1876-03-04      Scotland      England           3           0
# ...           ...           ...          ...         ...         ...
# 41535  2019-11-19    Kyrgyzstan   Tajikistan           1           1
# 41536  2019-11-19       Vietnam     Thailand           0           0
# 41537  2019-11-19      Malaysia    Indonesia           2           0
# 41538  2019-11-19  Turkmenistan    Sri Lanka           2           0
# 41539  2019-11-19       Lebanon  North Korea           0           0
#
#                          tournament          city       country  neutral  year
# ...

# %%
fifa = dfa[dfa['tournament']=='FIFA World Cup']

# %%
fifa
# Out:
#              date  home_team      away_team  home_score  away_score  \
# 1304   1930-07-13    Belgium  United States           0           3
# 1305   1930-07-13     France         Mexico           4           1
# 1306   1930-07-14     Brazil     Yugoslavia           1           2
# 1307   1930-07-14       Peru        Romania           1           3
# 1308   1930-07-15  Argentina         France           1           0
# ...           ...        ...            ...         ...         ...
# 39928  2018-07-07     Russia        Croatia           2           2
# 39929  2018-07-10     France        Belgium           1           0
# 39930  2018-07-11    Croatia        England           2           1
# 39931  2018-07-14    Belgium        England           2           0
# 39932  2018-07-15     France        Croatia           4           2
#
#            tournament            city  country  neutral  year
# 1304   FIFA World Cup      Montevideo  Uruguay     True  1930
# ...

# %%
fifa.year.unique()
# Out:
# array([1930, 1934, 1938, 1950, 1954, 1958, 1962, 1966, 1970, 1974, 1978,
#        1982, 1986, 1990, 1994, 1998, 2002, 2006, 2010, 2014, 2018],
#       dtype=int64)

# %%
{1930:'uruguay', 1934:'italy'}
