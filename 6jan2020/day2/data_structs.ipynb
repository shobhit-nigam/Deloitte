# %%
lista = ['netflix', 'prime', 'hotstar', 'zee5', 'disney', 'hbo', 'tv+']

# %%
listb = ('netflix', 'prime', 'hotstar', 'zee5', 'disney', 'hbo', 'tv+')

# %%
type(listb)
# Out:
# tuple

# %%
listb.append(lista)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-319c1edc0a7f> in <module>
# ----> 1 listb.append(lista)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
listb.pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-370f2c74ab47> in <module>
# ----> 1 listb.pop()
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
listb[4]
# Out:
# 'disney'

# %%
len(listb)
# Out:
# 7

# %%
listb.count('hbo')
# Out:
# 1

# %%
listc = ('netflix', 'prime', 'hotstar', 'zee5', 'disney', 'hbo', 'tv+', 'hbo')

# %%
listc.count('hbo')
# Out:
# 2

# %%
listc = ('netflix', 'prime', 'hotstar', ['zee5', 'disney'], 'hbo', 'tv+', 'hbo')

# %%
listc[3][0] = 'zeefive'

# %%
#listc[3][0][1] = 'zeefive'

# %%
seta = {4, 7, 8, 10, 7, 1, 12, 8}
setb = {4, 3, 9, 5, 12, 8}

# %%
print(seta)
print(setb)
# Out:
# {1, 4, 7, 8, 10, 12}
# {3, 4, 5, 8, 9, 12}

# %%
setc = {'netflix', 'prime', 'hotstar', 'zee5', 'disney', 'hbo', 'tv+', 'hbo'}

# %%
setc
# Out:
# {'disney', 'hbo', 'hotstar', 'netflix', 'prime', 'tv+', 'zee5'}

# %%
setc[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-c498659350b4> in <module>
# ----> 1 setc[0]
#
# TypeError: 'set' object is not subscriptable

# %%
x = setc.pop()

# %%
x
# Out:
# 'zee5'

# %%
setc
# Out:
# {'disney', 'hbo', 'hotstar', 'netflix', 'prime', 'tv+'}

# %%
setd = {'netflix', 'prime', 'hotstar', 'zee5',( 'disney', ['hbo', 'tv+'], 'hbo')}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-4baf2a8734d0> in <module>
# ----> 1 setd = {'netflix', 'prime', 'hotstar', 'zee5',( 'disney', ['hbo', 'tv+'], 'hbo')}
#
# TypeError: unhashable type: 'list'

# %%
seta
# Out:
# {1, 4, 7, 8, 10, 12}

# %%
setb
# Out:
# {3, 4, 5, 8, 9, 12}

# %%
setf = seta | setb

# %%
setf
# Out:
# {1, 3, 4, 5, 7, 8, 9, 10, 12}

# %%
setf = seta & setb

# %%
setf
# Out:
# {4, 8, 12}

# %%
seta ^ setb
# Out:
# {1, 3, 5, 7, 9, 10}

# %%
seta = {4, 7, 8, 10, 7, 1, 12, 8}
setb = {4, 3, 9, 5, 12, 8}

# %%
seta + setb
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-3bbc36065103> in <module>
# ----> 1 seta + setb
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
avenger = {'thor':'hammer', 'captain':'shield', 'panther':'vibranium'}

# %%
avenger = {'thor':'hammer', 'captain':['shield', 'hammer'], 'panther':'vibranium'}

# %%
avenger['thor']
# Out:
# 'hammer'

# %%
marvel = {'Wolverine':'claws', 'avenger':avenger, 'mystique':'shape shift' }

# %%
marvel['avenger']['captain'][0]
# Out:
# 'shield'

# %%
avenger['thor']= 'thunder'

# %%
avenger
# Out:
# {'thor': 'thunder', 'captain': ['shield', 'hammer'], 'panther': 'vibranium'}

# %%
avenger['hawkeye'] = 'arrows'

# %%
avenger['captain'].insert(0, 'doesnt get old')

# %%
avenger
# Out:
# {'thor': 'thunder',
#  'captain': ['doesnt get old', 'shield', 'hammer'],
#  'panther': 'vibranium',
#  'hawkeye': 'arrows'}

# %%
for val in avenger:
    print(val, ':', avenger[val])
# Out:
# thor : thunder
# captain : ['doesnt get old', 'shield', 'hammer']
# panther : vibranium
# hawkeye : arrows

# %%
avenger.keys()
# Out:
# dict_keys(['thor', 'captain', 'panther', 'hawkeye'])

# %%
x = avenger.values()

# %%
type(x)
# Out:
# dict_values

# %%
x = list(avenger.keys())

# %%
x
# Out:
# ['thor', 'captain', 'panther', 'hawkeye']

# %%
var = avenger.items()

# %%
var
# Out:
# dict_items([('thor', 'thunder'), ('captain', ['doesnt get old', 'shield', 'hammer']), ('panther', 'vibranium'), ('hawkeye', 'arrows')])

# %%
for k, v in avenger.items():
    print(k, ":", v)
# Out:
# thor : thunder
# captain : ['doesnt get old', 'shield', 'hammer']
# panther : vibranium
# hawkeye : arrows
